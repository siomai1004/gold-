# %% [markdown]
# <a href="https://colab.research.google.com/github/siomai1004/gold-/blob/main/gold_fa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (" Hello grade 7 !")
# Out:
#  Hello grade 7 !
